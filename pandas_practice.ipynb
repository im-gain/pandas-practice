# %% [markdown]
# <a href="https://colab.research.google.com/github/im-gain/pandas-practice/blob/main/pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 판다스 시작하기

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# ## 데이터셋 불러오기
#
# gapminder는 스웨덴의 비영리 통계분석 서비스이다. 유엔의 데이터를 바탕으로 한 인구 예측, 부의 이동 등에 관한 연구논문과 통계정보를 공유한다.
#
# ---
# 컬럼 정보
# * country : 국가
# * continent : 대륙
# * year : 연도
# * lifeExp : 평균 수명
# * pop : 인구
# * gdpPercap : 1인당 GDP

# %% [markdown]
# ### 판다스 임포트

# %%
# 판다스 라이브러리를 임포트합니다

import pandas as pd

# %% [markdown]
# ### gapminder.tsv를 df에 저장

# %%
# (예시) df = pd.read_csv('/gdrive/My Drive/220205/gapminder.tsv', sep='\t')

df = pd.read_csv('/gdrive/My Drive/Pandas_practice/gapminder.tsv', sep='\t')
# gapminder.tsv 파일이 있는 경로를 찾는 것 
# pd.read_csv를 df(변수)에 저장, 구글 드라이브, 내 드라이브에 pandas_practice라는 폴더를 만들었고 그 안에 있다는 의미

# %% [markdown]
# * 본인 경로에 맞게 **`절대경로`**로 설정한다.

# %% [markdown]
# ### head()를 사용하여 5개만 불러오기

# %%
# head()를 사용하여 5개만 불러오기

df.head(10)  #위에서 부터 몇개의 행을 보여줄지를 결정(데이터를 대략적으로 보여줌)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %% [markdown]
# * head 파라미터 숫자를 바꿔 넣어보자

# %% [markdown]
# ### shape로 df의 행과 열 개수 출력

# %%
# shape로 df의 행과 열 개수 출력
# 주의! shape는 괄호를 적지 않는다. 왜냐하면 메소드를 호출하는 것이 아닌 데이터프레임의 속성 그 차제이기 때문

df.shape
# Out:
# (1704, 6)

# %% [markdown]
# ### df의 열 이름 확인하기

# %%
# df의 열 이름 확인하기

df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %% [markdown]
# ### 각 열의 데이터 타입 알아보기(dtypes, info())

# %%
# dtypes 속성으로 각 열의 데이터 타입 알아보기

df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %% [markdown]
# * 판다스의 object 자료형 == 파이썬의 string(문자열) 자료형
#
# object는 문자열
# int 는 정수
# float는 실수

# %%
# info() 메서드로 각 열의 데이터 타입 알아보기

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ## 데이터 추출하기

# %% [markdown]
# ### 행 단위로 데이터 추출하기

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %% [markdown]
# * 인덱스 : 위의 DataFrame에서 왼쪽의 번호가 인덱스이다. 숫자 대신 first, second, third 같은 문자열로 지정할 수도 있다.
# * 행번호 : 데이터의 순서를 따라간다. 실제 데이터프레임 값에서 확인할 수 없으며 정수만으로 데이터를 조회한다.

# %% [markdown]
# #### (1) loc을 사용하여 인덱스 기준으로 행 데이터 추출하기

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
# 대괄호를 두 겹으로 만들면 데이터프레임 테이블 형태로 출력이 가능하다.

df.loc[[0]]
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314

# %%
# 여러 행을 테이블 형태로 출력하기

df.loc[[0, 99, 999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %% [markdown]
# #### (2) iloc을 사용하여 행번호 기준으로 행 데이터 추출하기

# %%
df.iloc[0:9]  #0부터 9-1행까지 추출(인덱싱)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395

# %%
# 여러 개의 데이터 한 번에 추출하기
df.iloc[[0, 99, 999]]

# %%
# 마지막 행은 어떻게 출력할까?
df.iloc[[-1 ]] # 마지막행 출력을 위해 음수를 사용해도 에러가 나지 않는다
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.loc[[-1]]  #loc는 인덱스 개념으로 출력하기 때문에 -1이라는 이름을 가진 인덱스가 없어서 오류 발생
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-09d4638e49ed> in <module>
# ----> 1 df.loc[[-1]]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
# ...

# %% [markdown]
# * 데이터의 행과 열을 지정하여 출력하려면 df.loc[[행], [열]] 또는 df.iloc[[행], [열]]로 추출합니다.

# %%
# 모든 행 데이터의 year, pop 열 추출하기. (loc사용시 문자열로 리스트를 전달해야 함)
df.loc[:, ['year', 'pop']]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# ...    ...       ...
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143
#
# [1704 rows x 2 columns]

# %%
# 모든 행 데이터의 year, pop 열 추출하기. (iloc사용시 정수로 리스트를 전달해야 함)

df.iloc[:, [2,4]]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# ...    ...       ...
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143
#
# [1704 rows x 2 columns]

# %% [markdown]
# #### 몸풀기 : country,  gdpPercap 열 추출을 위해 loc와 iloc을 어떻게 사용해야 할까?

# %%
# loc로 모든 행 데이터의  country, gdpPercap 열 추출하기

df.loc[:,['country','gdpPercap']]
# Out:
#           country   gdpPercap
# 0     Afghanistan  779.445314
# 1     Afghanistan  820.853030
# 2     Afghanistan  853.100710
# 3     Afghanistan  836.197138
# 4     Afghanistan  739.981106
# ...           ...         ...
# 1699     Zimbabwe  706.157306
# 1700     Zimbabwe  693.420786
# 1701     Zimbabwe  792.449960
# 1702     Zimbabwe  672.038623
# 1703     Zimbabwe  469.709298
#
# [1704 rows x 2 columns]

# %%
# iloc로 모든 행 데이터의  country, gdpPercap 열 추출하기

df.iloc[:,[0,5]]
# Out:
#           country   gdpPercap
# 0     Afghanistan  779.445314
# 1     Afghanistan  820.853030
# 2     Afghanistan  853.100710
# 3     Afghanistan  836.197138
# 4     Afghanistan  739.981106
# ...           ...         ...
# 1699     Zimbabwe  706.157306
# 1700     Zimbabwe  693.420786
# 1701     Zimbabwe  792.449960
# 1702     Zimbabwe  672.038623
# 1703     Zimbabwe  469.709298
#
# [1704 rows x 2 columns]

# %%
# loc를 사용해서 인덱스가 10인 행부터 13인 행의 country, lifeExp, gdpPercap 열 데이터 추출하기
# 주의! loc는 인덱스 기준으로 행을 찾아가므로 슬라이싱을 할 때 [이상:이하]로 인식한다.

df.loc[10:13,['country','lifeExp','gdpPercap']]
# Out:
#         country  lifeExp    gdpPercap
# 10  Afghanistan   42.129   726.734055
# 11  Afghanistan   43.828   974.580338
# 12      Albania   55.230  1601.056136
# 13      Albania   59.280  1942.284244

# %%
# iloc를 사용해서 인덱스가 10인 행부터 13인 행의 country, lifeExp, gdpPercap 열 데이터 추출하기

df.iloc[10:14,[0,3,5]]
# Out:
#         country  lifeExp    gdpPercap
# 10  Afghanistan   42.129   726.734055
# 11  Afghanistan   43.828   974.580338
# 12      Albania   55.230  1601.056136
# 13      Albania   59.280  1942.284244

# %% [markdown]
# ## 기초 통계 계산하기

# %% [markdown]
# ### lifeExp 열을 연도별로 그룹화하여 평균 계산하기

# %%
df.groupby('year')[['lifeExp']].mean() # 앗 어렵다.. 의미를 이해하자

# 데이터프레임 형태로 출력하려면 어떻게 해야할까?
# Out:
#         lifeExp
# year
# 1952  49.057620
# 1957  51.507401
# 1962  53.609249
# 1967  55.678290
# 1972  57.647386
# 1977  59.570157
# 1982  61.533197
# 1987  63.212613
# 1992  64.160338
# 1997  65.014676
# 2002  65.694923
# 2007  67.007423

# %% [markdown]
# ### lifeExp, gdpPercap 열의 평균값을 연도, 대륙별로 그룹화하여 한 번에 계산하기

# %%
df.groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']].mean() 
# 연도와 대륙 기준으로 그룹핑을 하고, 평균수명과 gdp의 평균을 구하는 것
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %% [markdown]
# ### 그룹화한 데이터 개수 세기 (빈도)

# %%
# continent로 그룹화하여 country 열만 추출해서 데이터 빈도수 계산
df.groupby('continent')[['country']].nunique()
# Out:
#            country
# continent
# Africa          52
# Americas        25
# Asia            33
# Europe          30
# Oceania          2

# %% [markdown]
# ## 그래프 그리기

# %% [markdown]
# ### 시각화 라이브러리 불러오기

# %%
# matplotlib 라이브러리 불러오기 (별명: plt)

import matplotlib.pyplot as plt

# %% [markdown]
# * Matplotlib는 파이썬에서 자료를 차트(chart)나 플롯(plot)으로 시각화(visulaization)하는 패키지이다.

# %% [markdown]
# ### year 열을 기준으로 그룹화한 데이터프레임에서 lifeExp 열만 추출하여 평균값 구하기

# %%
global_yearly_life_expectancy = df.groupby('year')['lifeExp'].mean()
print(global_yearly_life_expectancy)
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %% [markdown]
# ### plot 메서드를 사용하여 그래프 그리기

# %%
# 연도별 기대수명 그래프
global_yearly_life_expectancy.plot(kind='bar')

# %% [markdown]
# ### 직접 그래프 그리기

# %%
plt.rc('font', family='NanumBarunGothic')
plt.title('한글') # 그래프 제목
plt.plot([1,2,3], [1,3,4]) # 그래프 좌표
plt.show() # 그래프 띄우기

# %%
plt.rc('font', family='NanumBarunGothic')
plt.title('한글') # 그래프 제목
plt.plot([1,2,3], [1,3,4],".",color="orange") # 그래프 좌표
plt.show() # 그래프 띄우기

# %%
plt.rc('font', family='NanumBarunGothic')
plt.title('한글') # 그래프 제목
plt.plot([1,2,3], [1,3,4],".",color="pink") # 그래프 좌표
plt.show() # 그래프 띄우기

# %%
plt.rc('font', family='NanumBarunGothic')
plt.title('한글') # 그래프 제목
plt.plot([1,2,3], [1,3,4],"^",color="orange") # 그래프 좌표
plt.show() # 그래프 띄우기

# %%
plt.rc('font', family='NanumBarunGothic')
plt.title('한글') # 그래프 제목
plt.plot([1,2,3], [1,3,4],":",color="orange") # 그래프 좌표
plt.show() # 그래프 띄우기

# %%
# 한글 깨짐 해결
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 런타임 다시 실행
# 런타임 다시 실행 후 이 셀은 다시 실행하지 않아도 됨
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (19.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %% [markdown]
# # 미션 4
# #### 그래프 그리기 실습 : 주어진 조건에 맞게 꺾은선 그래프를 띄워보자
# 1. 제목 : 수업 시간과 피로도
# 2. x축 값 : 10, 20, 30, 40, 50, 60
# 3. y축 값 : 5, 12, 29, 25, 30, 35
# 4. x축 이름 : 수업시간 (분)
# 5. y축 이름 : 피로도

# %%
x = [10,20,30,40,50,60]
y = [5,12,29,25,30,35]
plt.title('수업 시간과 피로도') # 그래프 제목
plt.plot(x, y) # 그래프 좌표
plt.xlabel('수업시간(분)')
plt.ylabel('피로도')
plt.show() # 그래프 띄우기

# %% [markdown]
# #  판다스 더 나아가기

# %% [markdown]
# ## 시리즈, 데이터프레임 만들기

# %% [markdown]
# ### (1) 시리즈 만들기

# %%
# 판다스의 Series 메서드에 리스트를 전달하여 시리즈 생성

s = pd.Series(['banana', 42])
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6fae52778f12> in <module>
#       1 # 판다스의 Series 메서드에 리스트를 전달하여 시리즈 생성
#       2
# ----> 3 s = pd.Series([['banana', 42]])
#       4 print(s)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### (2) 데이터프레임 만들기

# %%
# 딕셔너리를 DataFrame클래스에 전달하여 딕셔너리 생성

scientists = pd.DataFrame({
    'Name': ['Rosaline Franklin', 'William Gosset'],
    'Occupation': ['Chemist', 'Statistician'],
    'Born': ['1920-04-16', '1876-06-13'],
    'Died': ['1958-04-16', '1937-10-16'],
    'Age': [37, 61]
})
print(scientists)

# 0과 1 인덱스가 자동으로 생성됨을 알 수 있다.
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-04-16  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %% [markdown]
# ## 데이터프레임 다루기

# %% [markdown]
# ### scientists.csv 파일 임포트

# %%
# (예시) scientists = pd.read_csv('/gdrive/My Drive/220205/scientists.csv')

# 나의 절대 로 작성
scientists = pd.read_csv('/gdrive/My Drive/Pandas_practice/scientists.csv')

scientists.head()
# Out:
#                    Name        Born        Died  Age    Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist

# %% [markdown]
# ### 통계내기

# %%
# 나이의 최소값
print(scientists['Age'].min())
# 나이의 최대값
print(scientists['Age'].max())
# 나이의 평균
print(scientists['Age'].mean())
# Out:
# 37
# 90
# 59.125

# %% [markdown]
# ### 조건을 만족하는 행만 추출하기

# %%
# 평균보다 나이가 어리다는 조건을 만족하는 행만 추출

scientists[scientists['Age'] < scientists['Age'].mean()]
# Out:
#                 Name        Born        Died  Age          Occupation
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 4      Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5          John Snow  1813-03-15  1858-06-16   45           Physician
# 6        Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist

# %% [markdown]
# ## 데이터프레임의 데이터 처리하기

# %% [markdown]
# ### 날짜를 datetime 자료형으로 바꾸기

# %% [markdown]
# Born과 Died 열은 Object(문자열)이다. 날짜이므로 datetime이라는 자료형으로 바꿔보자.

# %%
print(scientists['Born'].dtype)
print(scientists['Died'].dtype)
# Out:
# object
# object

# %%
# Born 열을 datetime 자료형으로 바꿔서 born_datetime 변수에 저장하기
born_datetime = pd.to_datetime(scientists['Born'], format='%Y-%m-%d')
print(born_datetime)
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
# Died 열을 datetime 자료형으로 바꿔서 died_datetime 변수에 저장하기
died_datetime = pd.to_datetime(scientists['Died'], format='%Y-%m-%d')
print(died_datetime)
# Out:
# 0   1958-04-16
# 1   1937-10-16
# 2   1910-08-13
# 3   1934-07-04
# 4   1964-04-14
# 5   1858-06-16
# 6   1954-06-07
# 7   1855-02-23
# Name: Died, dtype: datetime64[ns]

# %% [markdown]
# ### 새로운 열 추가하기

# %% [markdown]
# datetime으로 바꾼 것을 scientists 데이터프레임에 새로운 열로 추가한다

# %%
# born_dt, died_dt 추가
scientists['born_dt'] = born_datetime
scientists['died_dt'] = died_datetime
scientists.head()
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt
# 0 1958-04-16
# 1 1937-10-16
# 2 1910-08-13
# 3 1934-07-04
# 4 1964-04-14

# %% [markdown]
# ### 시간 계산하기

# %% [markdown]
# died_dt열에서 born_dt를 빼면 살아있던 시간을 계산할 수 있다.

# %%
# 과학자들이 살아있던 날 계산하여 열에 추가
scientists['age_days_dt'] = scientists['died_dt'] - scientists['born_dt']
scientists.head()
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt age_days_dt
# 0 1958-04-16  13779 days
# 1 1937-10-16  22404 days
# 2 1910-08-13  32964 days
# 3 1934-07-04  24345 days
# 4 1964-04-14  20777 days

# %% [markdown]
# ### 열 삭제하기

# %% [markdown]
# 열을 통째로 삭제하려면 drop() 함수를 사용한다.

# %%
# age_days_dt 열 삭제
scientists_dropped = scientists.drop(['age_days_dt'], axis=1) # axis = 1 : 열 방향으로 동작한다 / axis = 0 : 행 방향으로 동작한다
scientists_dropped
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#      born_dt    died_dt
# 0 1920-07-25 1958-04-16
# 1 1876-06-13 1937-10-16
# 2 1820-05-12 1910-08-13
# 3 1867-11-07 1934-07-04
# 4 1907-05-27 1964-04-14
# 5 1813-03-15 1858-06-16
# 6 1912-06-23 1954-06-07
# 7 1777-04-30 1855-02-23

# %%
scientists.head()
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt age_days_dt
# 0 1958-04-16  13779 days
# 1 1937-10-16  22404 days
# 2 1910-08-13  32964 days
# 3 1934-07-04  24345 days
# 4 1964-04-14  20777 days

# %%
scientists_dropped = scientists.drop(['age_days_dt'], axis=1, inplace=True) #원본 데이터에서도 삭제

# %%
scientists.head()
# Out:
#                    Name        Born        Died  Age    Occupation    born_dt  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1        William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
# 2  Florence Nightingale  1820-05-12  1910-08-13   90         Nurse 1820-05-12
# 3           Marie Curie  1867-11-07  1934-07-04   66       Chemist 1867-11-07
# 4         Rachel Carson  1907-05-27  1964-04-14   56     Biologist 1907-05-27
#
#      died_dt
# 0 1958-04-16
# 1 1937-10-16
# 2 1910-08-13
# 3 1934-07-04
# 4 1964-04-14

# %% [markdown]
# ## 3. 데이터 저장하고 불러오기

# %% [markdown]
# 잘 가공한 데이터는 안전하게 보관해야 다음에도 사용할 수 있다. 여기서는 가공한 데이터를 csv, 엑셀 파일로 저장하고 불러오는 방법을 알아본다.

# %%
# 저장하기
names = scientists['Name'] #name 열만 저장할 것이다. (시리즈)

# %% [markdown]
# ### (1) csv파일로 저장하기

# %%
names.to_csv('names.csv') # 저장할 경로 지정하기

# 작업폴더 안을 확인해보자

# %% [markdown]
# ### (2) 엑셀 파일로 저장하기

# %% [markdown]
# 시리즈 자료형은 to_frame() 함수를 사용해 데이터프레임으로 변환한 후에 엑셀로 저장해야 합니다.

# %%
names_df = names.to_frame()

# xlsx 확장자로 저장하기
import openpyxl
names_df.to_excel('names.xlsx')

# %%
from google.colab import drive
drive.mount('/gdrive')
